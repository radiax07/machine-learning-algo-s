# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = 2 * np.random.rand(500, 1)
y = 5 + 3 * X + np.random.randn(500, 1)

fig = plt.figure(figsize=(8,6))
# plt.style.use('dark_background')
plt.scatter(X, y)
plt.title("Dataset")
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %%
def hypothesis(X, w, b):
    return np.dot(X,w) + b

# %%
def loss(y, y_pred): 
    n = len(y)
    return (1/n) * (np.sum((y - y_pred) ** 2))

# %%
def gradient(X, y, y_pred):
    n = len(y)
    dw = -(2/n) * np.dot(X.T, (y - y_pred))
    db = -(2/n) * np.sum(y-y_pred)

    return dw, db

# %%
w , b =0,0
learning_rate = 0.01
epochs = 5000

for i in range(epochs):
    y_pred = hypothesis(X, w, b)

    model_loss = loss(y, y_pred)

    dw, db = gradient(X, y, y_pred)

    w = w - learning_rate*dw
    b = b - learning_rate*db

    if (i % 100 == 0):
        print(f"The loop ran {i} times and the loss is {model_loss}")
# Out:
# The loop ran 0 times and the loss is 65.66269686211602
# The loop ran 100 times and the loss is 1.1652451504595438
# The loop ran 200 times and the loss is 1.0228343113822607
# The loop ran 300 times and the loss is 0.9552710345551821
# The loop ran 400 times and the loss is 0.9204351563968391
# The loop ran 500 times and the loss is 0.9024731116734657
# The loop ran 600 times and the loss is 0.8932115379452503
# The loop ran 700 times and the loss is 0.8884360934318621
# The loop ran 800 times and the loss is 0.885973782925066
# The loop ran 900 times and the loss is 0.8847041685436443
# The loop ran 1000 times and the loss is 0.8840495310911122
# The loop ran 1100 times and the loss is 0.8837119875026581
# The loop ran 1200 times and the loss is 0.8835379435739679
# The loop ran 1300 times and the loss is 0.8834482031962801
# The loop ran 1400 times and the loss is 0.8834019313415359
# The loop ran 1500 times and the loss is 0.8833780726884224
# The loop ran 1600 times and the loss is 0.8833657707106538
# The loop ran 1700 times and the loss is 0.8833594275756789
# The loop ran 1800 times and the loss is 0.8833561569339928
# The loop ran 1900 times and the loss is 0.8833544705285984
# The loop ran 2000 times and the loss is 0.88335360098573
# The loop ran 2100 times and the loss is 0.8833531526327996
# The loop ran 2200 times and the loss is 0.8833529214534552
# The loop ran 2300 times and the loss is 0.8833528022529648
# The loop ran 2400 times and the loss is 0.8833527407909125
# The loop ran 2500 times and the loss is 0.883352709099903
# The loop ran 2600 times and the loss is 0.8833526927594125
# The loop ran 2700 times and the loss is 0.8833526843339434
# The loop ran 2800 times and the loss is 0.8833526799896102
# The loop ran 2900 times and the loss is 0.883352677749589
# The loop ran 3000 times and the loss is 0.8833526765945912
# The loop ran 3100 times and the loss is 0.8833526759990522
# The loop ran 3200 times and the loss is 0.883352675691981
# The loop ran 3300 times and the loss is 0.883352675533649
# The loop ran 3400 times and the loss is 0.8833526754520103
# The loop ran 3500 times and the loss is 0.8833526754099157
# The loop ran 3600 times and the loss is 0.8833526753882109
# The loop ran 3700 times and the loss is 0.8833526753770197
# The loop ran 3800 times and the loss is 0.8833526753712491
# The loop ran 3900 times and the loss is 0.8833526753682737
# The loop ran 4000 times and the loss is 0.8833526753667396
# The loop ran 4100 times and the loss is 0.8833526753659484
# The loop ran 4200 times and the loss is 0.8833526753655406
# The loop ran 4300 times and the loss is 0.8833526753653302
# The loop ran 4400 times and the loss is 0.8833526753652218
# The loop ran 4500 times and the loss is 0.8833526753651658
# The loop ran 4600 times and the loss is 0.883352675365137
# The loop ran 4700 times and the loss is 0.8833526753651222
# The loop ran 4800 times and the loss is 0.8833526753651146
# The loop ran 4900 times and the loss is 0.8833526753651106
