# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = 2 * np.random.rand(500, 1)
y = 5 + 3 * X + np.random.randn(500, 1)

fig = plt.figure(figsize=(8,6))
# plt.style.use('dark_background')
plt.scatter(X, y)
plt.title("Dataset")
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %%
def hypothesis(X, w, b):
    return np.dot(X,w) + b

# %%
def loss(y, y_pred): 
    n = len(y)
    return (1/n) * (np.sum((y - y_pred) ** 2))

# %%
def gradient(X, y, y_pred):
    n = len(y)
    dw = -(2/n) * np.dot(X.T, (y - y_pred))
    db = -(2/n) * np.sum(y-y_pred)

    return dw, db

# %%
w , b =0,0
learning_rate = 0.01
epochs = 2000

for i in range(epochs):
    y_pred = hypothesis(X, w, b)

    model_loss = loss(y, y_pred)

    dw, db = gradient(X, y, y_pred)

    w = w - learning_rate*dw
    b = b - learning_rate*db

    if (i % 100 == 0):
        print(f"The loop ran {i} times and the loss is {model_loss}")
# Out:
# The loop ran 0 times and the loss is 66.83199924186951
# The loop ran 100 times and the loss is 1.1413996246368578
# The loop ran 200 times and the loss is 1.012088135619955
# The loop ran 300 times and the loss is 0.9454668570802313
# The loop ran 400 times and the loss is 0.9088405336551449
# The loop ran 500 times and the loss is 0.8887042057361683
# The loop ran 600 times and the loss is 0.8776337060099373
# The loop ran 700 times and the loss is 0.8715473945095634
# The loop ran 800 times and the loss is 0.8682012774782056
# The loop ran 900 times and the loss is 0.8663616576712252
# The loop ran 1000 times and the loss is 0.8653502761198565
# The loop ran 1100 times and the loss is 0.8647942413138778
# The loop ran 1200 times and the loss is 0.8644885458965141
# The loop ran 1300 times and the loss is 0.8643204814386916
# The loop ran 1400 times and the loss is 0.8642280833837035
# The loop ran 1500 times and the loss is 0.8641772850133866
# The loop ran 1600 times and the loss is 0.8641493572130972
# The loop ran 1700 times and the loss is 0.8641340031372843
# The loop ran 1800 times and the loss is 0.864125561812095
# The loop ran 1900 times and the loss is 0.8641209209615599

# %%
w, b
# Out:
# (array([[3.01002926]]), np.float64(4.897403517504955))

# %%
fig = plt.figure(figsize=(8,6))
plt.scatter(X, y, label="Data")

best_fit_line = w*X + b

plt.plot(X,best_fit_line, color='red', label="Best Fit Line")

plt.title("Dataset with Best Fit Line")
plt.xlabel("First feature")
plt.ylabel("Second feature")

plt.legend()
plt.show()
